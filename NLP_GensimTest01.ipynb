# %% [markdown]
# ## GENSIM TEST
# # Martin Köhler 25.1.2019
# # siehe auch: https://www.machinelearningplus.com/nlp/gensim-tutorial/
# # How to create Topic Models with LDA?

# %%
from nltk.corpus import PlaintextCorpusReader
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk.probability
from nltk import Text
import nltk
import unicodecsv
from io import StringIO # M Köhler: wegen Python 3 
import numpy
import os
import sys, getopt
import re
import codecs

# %%
# Gensin: pip install --user gensim

# %%
import gensim
from doc2bow expects an array of unicode tokens on input, not a single string
from pprint import pprint

# %%
txtDir = "/." # das aktuelle Verzeichnis - geht sicher mit os.curdir() auch

# %%
textfile = codecs.open("Aggregatoren.txt", "r")# hier ohne "utf-8"... in MS-Word gespeichert
text = textfile.read()
textfile.close()
sentences = nltk.sent_tokenize(text,language='german')
words = nltk.word_tokenize(text,language='german') # hier neu
tokenized_sent = nltk.tokenize.word_tokenize(sentences[88],language='german')
print(tokenized_sent)
# Out:
# ['Versicherungsmakler', 'sind', 'dabei', 'sowohl', 'rechtlich', 'als', 'auch', 'wirtschaftlich', 'vom', 'Versicherungsunternehmen', 'unabhängig', '.']

# %%
print(len(sentences)) # Anzahl Sätze im Text "Aggregatoren"
# Out:
# 1701

# %%
from gensim.utils import simple_preprocess # dies "simpleprocess"-Funktion ist - wie es scheint sehr charmant...
from smart_open import smart_open
dictionary = corpora.Dictionary(simple_preprocess(line, deacc=True) for line in open('Aggregatoren.txt', encoding='CP1252'))
# mit der WIN-Unicode-Page "CP1252" geht es nun - der Text wurde in MS Word als .txt gespeichert

# %%
len(dictionary)
# Out:
# 3958

# %%
#dictionary = corpora.Dictionary(sentences)
print(dictionary)
# Out:
# Dictionary(3958 unique tokens: ['wegs', 'dern', 'prufung', 'differenzierten', 'betrach']...)

# %%
dictionary.token2id
# Out:
# {'wegs': 1547,
#  'dern': 537,
#  'prufung': 2588,
#  'differenzierten': 1120,
#  'betrach': 2748,
#  'parlaments': 3576,
#  'aggregatoren': 0,
#  'sches': 3360,
#  'methoden': 3295,
#  'grenzen': 1264,
#  'fproductid': 3334,
#  'vertreter': 603,
#  'elektronischen': 1025,
#  'ropo': 138,
#  'gesamtvertriebs': 2625,
#  'lierten': 1945,
#  'wissenschaftler': 2454,
#  'anreizen': 3081,
#  'betroffen': 1818,
#  'sationen': 1980,
#  'dienen': 2332,
#  'basis': 326,
#  'bewertet': 3197,
#  'antwortvorgaben': 2505,
#  'jah': 211,
#  'vorstel': 449,
#  'zwei': 1959,
#  'planen': 2896,
#  'hinge': 743,
#  'gultigen': 241,
#  'gesamte': 3797,
#  'prognostiziert': 2700,
#  'sachlichen': 2213,
#  'funfte': 454,
#  'pkw': 131,
#  'bestehen': 693,
#  'bojew': 3288,
#  'relationships': 3363,
#  'hat': 1895,
#  'zielsetzung': 2342,
#  'beteiligten': 3109,
#  'len': 511,
#  'sueddeutsche': 3377,
#  'vieler': 975,
#  'schwerer': 2966,
#  'mindes': 2644,
#  'neugeschafts': 1079,
# ...

# %%
from nltk.corpus import stopwords
from gensim.models import LdaModel, LdaMulticore
import gensim.downloader as api
from gensim.utils import simple_preprocess, lemmatize
from nltk.corpus import stopwords
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s')
logging.root.setLevel(level=logging.INFO)

# %%
stop_words = stopwords.words('german')

# %%
# stop_words = stop_words + ['xxx', 'xxx', 'xxx', 'xxx', 'xxx', 'xxx', 'xxx', 'xxx']

# %%
dataset = text # mal umbiegen

# %%
data = [d for d in dataset] # eine Liste von Buchstaben?

# %%
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 200345

# %% [raw]
# words
